# %%
import fake_useragent
import requests
from bs4 import BeautifulSoup as Soup
from bs4 import BeautifulSoup
import pandas as pd

# %%
url='http://stat.prtcom.ru/?mode=auth'
user=fake_useragent.UserAgent().random
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\git\pyython\парсер инет провайдера.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/git/pyython/%D0%BF%D0%B0%D1%80%D1%81%D0%B5%D1%80%20%D0%B8%D0%BD%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D0%B2%D0%B0%D0%B9%D0%B4%D0%B5%D1%80%D0%B0.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> url='http://stat.prtcom.ru/?mode=auth'
# ----> <a href='vscode-notebook-cell:/d%3A/git/pyython/%D0%BF%D0%B0%D1%80%D1%81%D0%B5%D1%80%20%D0%B8%D0%BD%D0%B5%D1%82%20%D0%BF%D1%80%D0%BE%D0%B2%D0%B0%D0%B9%D0%B4%D0%B5%D1%80%D0%B0.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> user=fake_useragent.UserAgent().random
#
# NameError: name 'fake_useragent' is not defined

# %%
header ={
    'user-agent': user
}
data={
    'user': 'CiganokMS',
    'passw': 'On4amKSE'
}

# %%
session= requests.Session()
responce = session.post(url, data=data, headers=header).text
soup = BeautifulSoup(responce, 'lxml')
print(soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html>
# <head>
# <title>Web-ïîðòàë àáîíåíòà</title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <link href="styles.css" media="screen" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
#   <!--
#    function query_detail()
#    {
#     if((document.det_form.amts_s.checked) || (document.det_form.amts_f.checked) ||
#        (document.det_form.inet_sess_f.checked) ||
#        (document.det_form.razo_s.checked) || (document.det_form.razo_f.checked) ||
#        (document.det_form.apus_s.checked) || (document.det_form.apus_f.checked))
#     {
#      if(window.confirm(' Çàãðóçêà äàííûõ ìîæåò çàíÿòü íåñêîëüêî \n\r ìèíóò. Ïðîäîëæèòü?'))
#      {
#       if(document.det_form.format_pdf.checked)
#       {
#        document.det_form.action = 'detail.php';
#        document.det_form.submit();
#       }
#       else
#       {
#        document.det_form.action = '';
#        document.det_form.submit();
#       }
#      }
#      else
#      {
#       return false;
#      }
#     }
#     else
#     {
#      window.alert('Íåîáõîäèìî âûáðàòü õîòÿ áû îäíó óñëóãó!');
#      return false;
#     }
#    }
#
#    function checkpass()
#    {
#     if((document.change_pass_form.reg_pass_old.value == '') ||
#        (document.change_pass_form.reg_pass_new.value == '') ||
#        (document.change_pass_form.reg_pass_newcon.value == ''))
#     {
#      window.alert('Âñå ïîëÿ äîëæíû áûòü çàïîëíåíû!');
#      return false;
#     }
#     else
#     {
#      if(document.change_pass_form.reg_pass_new.value == document.change_pass_form.reg_pass_newcon.value)
#      {
#       document.change_pass_form.submit();
#      }
#      else
#      {
#       window.alert('Ïàðîëè äîëæíû ñîâïàäàòü!');
#       return false;
#      }
#     }
#    }
#
#    function load_tarplans()
#    {
#
#
#
#
#     var type_acc = inet_accounts[document.change_tp_form.inet_logins.value];
#
#     var objDDL = document.change_tp_form.inet_tarplans;
#
#     objDDL.options.length = 0;
#
#     for(i=0; i<inet_tp.length; i=i+1)
#     {
#       if(inet_tp[i].tp_type == type_acc)
#       {
#        var theText = inet_tp[i].tp_name;
#        var theValue = inet_tp[i].tp_code;
#        var option = new Option(theText, theValue);
#
#        objDDL.options.add(option, objDDL.options.length);
#       }
#     }
#
#     if(type_acc > -1)
#     {
#      document.change_tp_form.curr_inet_tarplans.value = curr_inet_tp[document.change_tp_form.inet_logins.value];
#     }
#     else
#     {
#      document.change_tp_form.curr_inet_tarplans.value = "";
#     }
#    }
#
#
#    function changetp()
#    {
#     if(document.change_tp_form.inet_tarplans.options[document.change_tp_form.inet_tarplans.selectedIndex].text == document.change_tp_form.curr_inet_tarplans.value)
#      window.alert('Âûáðàííûé òàðèôíûé ïëàí ñîâïàäàåò ñ òåêóùèì. Âûáåðèòå äðóãîé!');
#    }
#   -->
#   </script>
# </head>
# <body>
# <div id="top">
# <!--  Áëîê àóòåíòèôèêàöèè -->
# <div id="auth">
# <form action="?mode=logout" method="post">
# <table>
# <tr>
# <td>ËÎÃÈÍ<br/><input class="input" disabled="" maxlength="32" name="user" type="text" value="CiganokMS"/></td>
# <td> </td>
# </tr>
# <tr>
# <td>ÏÀÐÎËÜ<br/><input class="input" disabled="" maxlength="15" name="passw" type="password" value=""/></td>
# <td><br/><input class="button_out" type="submit" value=""/></td>
# </tr>
# </table>
# </form>
# </div>
# </div>
# <div id="menu">
# <!-- Ìåíþ -->
# <div class="left" style="margin-left: 13em;">
# <!--<img src="images/menu_split.gif" alt="" />-->
# <!--<a href="?mode=acompany" title="Èíôîðìàöèÿ î êîìïàíèè">Î&nbsp;&nbsp;êîìïàíèè</a>-->
# <span>    </span>
# <a href="?mode=aabonent" title="Èíôîðìàöèÿ îá àáîíåíòå">Èíôîðìàöèÿ</a>
# <a href="?mode=state" title="Ñîñòîÿíèå ñ÷åòà">Ñ÷åò</a>
# <a href="?mode=detail" title="Äåòàëèçàöèÿ">Äåòàëèçàöèÿ</a>
# <a href="?mode=config" title="Ñìåíà òàðèôíîãî ïëàíà">Ñìåíà òàðèôà</a>
# <a href="?mode=akt" title="ÀÊÒ">ÀÊÒ</a>
# <a href="?mode=subscribe" title="Ïîäïèñêà">Ïîäïèñêà</a>
# </div>
# </div>
# <div id="head">
# <!-- Îñíîâíîé áëîê -->
# <div id="headermode">
# <table>
# <tr>
# <td align="left">ÑÎÑÒÎßÍÈÅ Ñ×ÅÒÀ ÍÀ 25/09/2022  14:03</td>
# <td align="right"><form action="" method="get" name="params_form">
# <input name="mode" type="hidden" value="state"/>
# <select name="month" onchange="javascript:document.params_form.submit()"><option label="ßíâàðü 2020" value="1577822400">ßíâàðü 2020</option>
# <option label="Ôåâðàëü 2020" value="1580500800">Ôåâðàëü 2020</option>
# <option label="Ìàðò 2020" value="1583006400">Ìàðò 2020</option>
# <option label="Àïðåëü 2020" value="1585684800">Àïðåëü 2020</option>
# <option label="Ìàé 2020" value="1588276800">Ìàé 2020</option>
# <option label="Èþíü 2020" value="1590955200">Èþíü 2020</option>
# <option label="Èþëü 2020" value="1593547200">Èþëü 2020</option>
# <option label="Àâãóñò 2020" value="1596225600">Àâãóñò 2020</option>
# <option label="Ñåíòÿáðü 2020" value="1598904000">Ñåíòÿáðü 2020</option>
# <option label="Îêòÿáðü 2020" value="1601496000">Îêòÿáðü 2020</option>
# <option label="Íîÿáðü 2020" value="1604174400">Íîÿáðü 2020</option>
# <option label="Äåêàáðü 2020" value="1606766400">Äåêàáðü 2020</option>
# <option label="ßíâàðü 2021" value="1609444800">ßíâàðü 2021</option>
# <option label="Ôåâðàëü 2021" value="1612123200">Ôåâðàëü 2021</option>
# <option label="Ìàðò 2021" value="1614542400">Ìàðò 2021</option>
# <option label="Àïðåëü 2021" value="1617220800">Àïðåëü 2021</option>
# <option label="Ìàé 2021" value="1619812800">Ìàé 2021</option>
# <option label="Èþíü 2021" value="1622491200">Èþíü 2021</option>
# <option label="Èþëü 2021" value="1625083200">Èþëü 2021</option>
# <option label="Àâãóñò 2021" value="1627761600">Àâãóñò 2021</option>
# <option label="Ñåíòÿáðü 2021" value="1630440000">Ñåíòÿáðü 2021</option>
# <option label="Îêòÿáðü 2021" value="1633032000">Îêòÿáðü 2021</option>
# <option label="Íîÿáðü 2021" value="1635710400">Íîÿáðü 2021</option>
# <option label="Äåêàáðü 2021" value="1638302400">Äåêàáðü 2021</option>
# <option label="ßíâàðü 2022" value="1640980800">ßíâàðü 2022</option>
# <option label="Ôåâðàëü 2022" value="1643659200">Ôåâðàëü 2022</option>
# <option label="Ìàðò 2022" value="1646078400">Ìàðò 2022</option>
# <option label="Àïðåëü 2022" value="1648756800">Àïðåëü 2022</option>
# <option label="Ìàé 2022" value="1651348800">Ìàé 2022</option>
# <option label="Èþíü 2022" value="1654027200">Èþíü 2022</option>
# <option label="Èþëü 2022" value="1656619200">Èþëü 2022</option>
# <option label="Àâãóñò 2022" value="1659297600">Àâãóñò 2022</option>
# <option label="Ñåíòÿáðü 2022" selected="selected" value="1661976000">Ñåíòÿáðü 2022</option>
# </select>
# </form>
# </td>
# </tr>
# </table>
# </div>
# <br/><br/><br/>
# <div class="mchidden" id="id1">
# <img alt="Ïî óñëóãàì" border="0" src="images/oborots.gif"/>
#    <a class="plushref" href="#" onclick="mc = document.getElementById('id1'); mc.className = mc.className=='mchidden'?' mcshowed':'mchidden'; return false;">ÏÎ ÓÑËÓÃÀÌ</a>
# <div class="mcbranch">
# <div id="box_container">
# <span id="box_header"> </span>
# <div id="box_inner">
# <div class="mchidden" id="id1">
# <div class="mcbranch">
# <table>
# <tr>
# <td id="bottom_right"> <b>ÍÀÈÌÅÍÎÂÀÍÈÅ ÓÑËÓÃÈ</b></td>
# <td id="bottom_right"> <b>ÂÕÎÄßÙÅÅ, ÐÓÁ</b></td>
# <td id="bottom_right"> <b>ÎÏËÀ×ÅÍÎ, ÐÓÁ</b></td>
# <td id="bottom_right"> <b>ÍÀ×ÈÑËÅÍÎ, ÐÓÁ</b></td>
# <td style="border-bottom: 1px solid;"> <b>ÒÅÊÓÙÅÅ, ÐÓÁ</b></td>
# </tr>
# <tr>
# <td style="border-right: 1px solid;"> Òåëåôîíèÿ                                         </td>
# <td align="right" style="border-right: 1px solid;">0,00 </td>
# <td align="right" style="border-right: 1px solid;">0,00 </td>
# <td align="right" style="border-right: 1px solid;">0,00 </td>
# <td align="right">0,00 </td>
# </tr>
# <tr>
# <td style="border-right: 1px solid;"> Èíòåðíåò                                          </td>
# <td align="right" style="border-right: 1px solid;">1059,46 </td>
# <td align="right" style="border-right: 1px solid;">0,00 </td>
# <td align="right" style="border-right: 1px solid;">516,67 </td>
# <td align="right" style="font-weight: bold; color: #f00;">542,79 </td>
# </tr>
# <tr>
# <td align="left" style="border-top: 1px solid;"> <b>Èòîãî</b></td>
# <td align="right" style="border-top: 1px solid;"><b>1059,46</b> </td>
# <td align="right" style="border-top: 1px solid;"><b>0,00</b> </td>
# <td align="right" style="border-top: 1px solid;"><b>516,67</b> </td>
# <td align="right" style="border-top: 1px solid #000; color: #f00;"><b>542,79</b> </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <br/><br/>
# <div class="mchidden" id="id2">
# <img alt="Íà÷èñëåíèÿ" border="0" src="images/charges.gif"/>
#    <a class="plushref" href="#" onclick="mc = document.getElementById('id2'); mc.className = mc.className=='mchidden'?' mcshowed':'mchidden'; return false;">ÍÀ×ÈÑËÅÍÈß</a>
# <div class="mcbranch">
# <div id="box_container">
# <span id="box_header"> </span>
# <div id="box_inner">
# <div class="mchidden" id="id2">
# <div class="mcbranch">
# <table>
# <tr>
# <td id="bottom_right"> <b>ØÈÔÐ</b></td>
# <td id="bottom_right"> <b>ÍÀÇÂÀÍÈÅ</b></td>
# <td id="bottom_right"> <b>ÎÁÎÐÎÒ</b></td>
# <td id="bottom_right"> <b>ÊÎË-ÂÎ</b></td>
# <td style="border-bottom: 1px solid;"> <b>ÑÓÌÌÀ</b></td>
# </tr>
# <tr>
# <td style="border-right: 1px solid;"> 10123</td>
# <td style="border-right: 1px solid;"> Áåçëèìèòíûé Ñòàðò 100 Ìáèò/ñ 620*                                                                   </td>
# <td style="border-right: 1px solid;"> Èíòåðíåò                                          </td>
# <td style="border-right: 1px solid;"> 0,83299999999999996.0</td>
# <td align="right">516,67 </td>
# </tr>
# <tr>
# <td align="left" colspan="4" style="border-top: 1px solid;"> <b>Èòîãî</b></td>
# <td align="right" style="border-top: 1px solid;"><b>516,67</b> </td>
# </tr>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <br/><br/>
# <div class="mchidden" id="id3">
# <img alt="Îïëàòû" border="0" src="images/pays.gif"/>
#    <a class="plushref" href="#" onclick="mc = document.getElementById('id3'); mc.className = mc.className=='mchidden'?' mcshowed':'mchidden'; return false;">ÎÏËÀÒÛ</a>
# <div class="mcbranch">
# <div id="box_container">
# <span id="box_header"> </span>
# <div id="box_inner">
# <div class="mchidden" id="id3">
# <div class="mcbranch">
#         Íåò äàííûõ ...
#        </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="footer">
# <div class="bottom">
# <div class="width auto_margin"><br/>
# <b>.</b>
# </div>
# </div>
# </div>
# </body>
# </html>
